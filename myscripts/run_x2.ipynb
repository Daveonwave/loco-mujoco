# %% [markdown]
# # Agibot X2

# %%
import numpy as np
from loco_mujoco.task_factories import RLFactory

# %%
# Create the environment. The factory will find "AgibotX2" because 
# you registered it inside the internal library structure.
env = RLFactory.make("AgibotX2")

action_dim = env.info.action_space.shape[0]
print(f"AgibotX2 loaded successfully with {action_dim} actuators!")

env.reset()
env.render()

i, absorbing = 0, False

# Main simulation loop
while True:
    if i == 1000 or absorbing:
        env.reset()
        i = 0
    
    # Send random noise to the actuators
    action = np.random.randn(action_dim)
    
    # Step the simulation
    obs, reward, absorbing, done, info = env.step(action)
    env.render()
    
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Create the environment. The factory will find "AgibotX2" because
#       2 # you registered it inside the internal library structure.
# ----> 3 env = RLFactory.make("AgibotX2")
#       5 action_dim = env.info.action_space.shape[0]
#       6 print(f"AgibotX2 loaded successfully with {action_dim} actuators!")
#
# File ~/Library/CloudStorage/OneDrive-PolitecnicodiMilano/Projects/loco-mujoco/loco_mujoco/task_factories/rl_factory.py:47, in RLFactory.make(env_name, init_state_type, terminal_state_type, goal_type, reward_type, **kwargs)
#      44 env_cls = LocoEnv.registered_envs[env_name]
#      46 # Create and return the environment
# ---> 47 return env_cls(init_state_type=init_state_type,
#      48                terminal_state_type=terminal_state_type,
#      49                goal_type=goal_type,
#      50                reward_type=reward_type,
#      51                **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-PolitecnicodiMilano/Projects/loco-mujoco/loco_mujoco/environments/humanoids/agibotx2.py:14, in AgibotX2.__init__(self, spec, **kwargs)
#      13 def __init__(self, spec=None, **kwargs):
# ---> 14     super().__init__(spec=spec or self.get_default_xml_file_path(), **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-PolitecnicodiMilano/Projects/loco-mujoco/loco_mujoco/environments/base.py:80, in LocoEnv.__init__(self, n_substeps, timestep, default_camera_mode, th_params, traj_params, **core_params)
#      77     super(LocoEnv, self).__init__(**core_params)
#      78 else:
#      79     # call grandparent constructor (Mujoco (CPU) environment)
# ---> 80     super(Mjx, self).__init__(**core_params)
#      82 # dataset dummy
#      83 self._dataset = None
#
# TypeError: Mujoco.__init__() missing 2 required positional arguments: 'actuation_spec' and 'observation_spec'
